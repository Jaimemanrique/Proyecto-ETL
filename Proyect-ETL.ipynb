# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np

import warnings
warnings.filterwarnings('ignore')


import pylab as plt
import seaborn as sns

from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

from selenium.webdriver.common.by import By   # para buscar segun tag, id, class, etc...
from selenium import webdriver
import time

from selenium import webdriver

# %%
fifa_23_ori = pd.read_csv('./fifa_23.csv')
fifa_23 = fifa_23_ori.copy()

# %%
fifa_23.head()
# Out:
#               Name  Ratings    Position           Version    PS  SKI  WF  \
# 0             Pelé       98         CAM   Icon  Explosive     0    5   4
# 1          Ronaldo       96          ST  Icon  Controlled     0    5   5
# 2  Zinedine Zidane       96         CAM  Icon  Controlled     0    5   5
# 3             Pelé       95  CF  CAM,ST   Icon  Explosive  4.2M    5   4
# 4    Ferenc Puskás       94          CF  Icon  Controlled     0    4   3
#
#       WR  PAC  SHO  PAS  DRI  DEF  PHY                          Body  \
# 0  H \ M   95   96   93   96   60   76   173cm | 5'8"  Unique (70kg)
# 1  M \ M   97   95   81   95   45   76       183cm | 6'0"  R9 (78kg)
# 2  M \ M   85   92   96   95   75   86  185cm | 6'1"  Average (77kg)
# 3  H \ M   96   93   90   95   56   75   173cm | 5'8"  Unique (69kg)
# 4  H \ M   91   96   91   92   46   76   172cm | 5'8"  Stocky (72kg)
#
#    Popularity   BS   IGS          Club League  Country
# 0        1790  516  2513  FUT 22 ICONS  Icons   Brazil
# ...

# %%
fc_barcelona = fifa_23[fifa_23['Club'] == 'FC Barcelona']
df_fc_barcelona = pd.DataFrame(fc_barcelona)
cols_mal_1 = ['Version','PS','SKI','WF','WR','Body','Popularity','BS','IGS']
df_fc_barcelona.drop(columns = cols_mal_1, inplace = True)
df_fc_barcelona
df_fc_barcelona.reset_index(drop = True, inplace = True)
df_fc_barcelona.drop(columns = 'Country', inplace = True)
df_fc_barcelona
# Out:
#                        Name  Ratings    Position  PAC  SHO  PAS  DRI  DEF  \
# 0        Robert Lewandowski       91      ST  CF   75   91   79   86   44
# 1        Robert Lewandowski       91      ST  CF   75   91   79   86   44
# 2              Gerard Piqué       89          CB   83   58   77   74   88
# 3                ter Stegen       88          GK   86   85   87   90   47
# 4           Frenkie de Jong       87          CM   82   69   86   87   77
# 5                  Raphinha       86      RW  RM   94   82   81   88   53
# 6                     Pedri       86          CM   80   69   83   88   69
# 7                     Pedri       85          CM   79   67   81   87   68
# 8           Sergio Busquets       85         CDM   42   62   79   79   82
# 9             Memphis Depay       85   CF  ST,LW   83   84   82   86   30
# 10         Jordi Alba Ramos       85     LB  LWB   84   70   82   82   77
# 11             Jules Koundé       84          CB   84   45   64   74   85
# ...

# %%
df_fc_barcelona.drop_duplicates(subset = ['Name'], inplace = True)

# %%
df_fc_barcelona.reset_index(drop = True, inplace = True)

# %%
df_fc_barcelona
# Out:
#                        Name  Ratings    Position  PAC  SHO  PAS  DRI  DEF  \
# 0        Robert Lewandowski       91      ST  CF   75   91   79   86   44
# 1              Gerard Piqué       89          CB   83   58   77   74   88
# 2                ter Stegen       88          GK   86   85   87   90   47
# 3           Frenkie de Jong       87          CM   82   69   86   87   77
# 4                  Raphinha       86      RW  RM   94   82   81   88   53
# 5                     Pedri       86          CM   80   69   83   88   69
# 6           Sergio Busquets       85         CDM   42   62   79   79   82
# 7             Memphis Depay       85   CF  ST,LW   83   84   82   86   30
# 8          Jordi Alba Ramos       85     LB  LWB   84   70   82   82   77
# 9              Jules Koundé       84          CB   84   45   64   74   85
# 10                   Kessié       84     CDM  CM   78   76   74   79   82
# 11          Ousmane Dembélé       83      RW  RM   93   77   79   87   36
# ...

# %%
real_madrid = fifa_23[fifa_23['Club'] == 'Real Madrid']
df_real_madrid = pd.DataFrame(real_madrid)
cols_mal = ['Version','PS','SKI','WF','WR','Body','Popularity','BS','IGS']
df_real_madrid.drop(columns = cols_mal, inplace = True)
df_real_madrid
df_real_madrid.reset_index(drop = True)
# Out:
#                             Name  Ratings      Position  PAC  SHO  PAS  DRI  \
# 0                  Karim Benzema       91        CF  ST   80   88   83   87
# 1               Thibaut Courtois       90            GK   84   89   75   90
# 2                    Luka Modric       89            CM   75   78   90   89
# 3                     Toni Kroos       89            CM   55   82   91   82
# 4                     Toni Kroos       88            CM   53   81   90   81
# 5                    Luka Modric       88            CM   73   76   89   88
# 6                    David Alaba       88            CB   81   66   85   83
# 7                    David Alaba       88            CB   81   66   85   83
# 8                Antonio Rüdiger       87            CB   82   53   71   67
# 9                Antonio Rüdiger       87            CB   82   53   71   67
# 10             Federico Valverde       87            CM   90   78   84   82
# ...

# %%
df_real_madrid.reset_index(drop = True, inplace = True)

df_real_madrid.drop(columns = 'Country', inplace = True)
df_real_madrid
# Out:
#                             Name  Ratings      Position  PAC  SHO  PAS  DRI  \
# 0                  Karim Benzema       91        CF  ST   80   88   83   87
# 1               Thibaut Courtois       90            GK   84   89   75   90
# 2                    Luka Modric       89            CM   75   78   90   89
# 3                     Toni Kroos       89            CM   55   82   91   82
# 4                     Toni Kroos       88            CM   53   81   90   81
# 5                    Luka Modric       88            CM   73   76   89   88
# 6                    David Alaba       88            CB   81   66   85   83
# 7                    David Alaba       88            CB   81   66   85   83
# 8                Antonio Rüdiger       87            CB   82   53   71   67
# 9                Antonio Rüdiger       87            CB   82   53   71   67
# 10             Federico Valverde       87            CM   90   78   84   82
# ...

# %%
df_real_madrid.drop_duplicates(subset = ['Name'], inplace = True)

# %%
df_real_madrid.reset_index(drop = True, inplace = True)

# %%
df_real_madrid
# Out:
#                             Name  Ratings      Position  PAC  SHO  PAS  DRI  \
# 0                  Karim Benzema       91        CF  ST   80   88   83   87
# 1               Thibaut Courtois       90            GK   84   89   75   90
# 2                    Luka Modric       89            CM   75   78   90   89
# 3                     Toni Kroos       89            CM   55   82   91   82
# 4                    David Alaba       88            CB   81   66   85   83
# 5                Antonio Rüdiger       87            CB   82   53   71   67
# 6              Federico Valverde       87            CM   90   78   84   82
# 7                Vinícius Júnior       86        LW  LM   95   79   74   90
# 8                   Éder Militão       84            CB   86   50   70   72
# 9                       Carvajal       84       RB  RWB   82   54   77   80
# 10                   Eden Hazard       84        LW  LM   83   80   82   87
# ...

# %%
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
url_fifa_22 = 'https://www.futwiz.com/en/fifa22/players?page=0&teams[]=243&order=rating&s=desc&release=nifgold'

# %%
PATH=ChromeDriverManager().install()
driver=webdriver.Chrome(PATH)

driver.get(url_fifa_22)

# %%
filas = driver.find_element(By.TAG_NAME, 'tbody')

data = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in filas.find_elements(By.TAG_NAME, 'tr')]

# %%
cols = ['','Name','Ratings','Positions','BIN','PAC','SHO','PAS','DRI','DEF','PHY','S/M','W/F','W/Rs','Foot','Stats']

# %%
df = pd.DataFrame(data, columns = cols)

# %%
df
# Out:
#                                           Name Ratings Positions    BIN  \
# 0                                       Player     OVR       POS    BIN
# 1           Karim Benzema\nReal Madrid | ESP 1      89        CF    19K
# 2        Thibaut Courtois\nReal Madrid | ESP 1      89        GK  28.8K
# 3                Casemiro\nReal Madrid | ESP 1      89       CDM   9.6K
# 4              Toni Kroos\nReal Madrid | ESP 1      88        CM    18K
# 5             Luka Modric\nReal Madrid | ESP 1      87        CM   9.4K
# 6                Carvajal\nReal Madrid | ESP 1      85        RB   4.6K
# 7             Eden Hazard\nReal Madrid | ESP 1      85        LW    15K
# 8             David Alaba\nReal Madrid | ESP 1      84        CB     6K
# 9         Antonio Rudiger\nReal Madrid | ESP 1      83        CB   3.5K
# 10      Federico Valverde\nReal Madrid | ESP 1      83        CM    12K
# 11          Ferland Mendy\nReal Madrid | ESP 1      83        LB   6.8K
# ...

# %%
df_cols_mal = ['S/M','W/F','W/Rs','Foot','Stats']
df.drop(columns = df_cols_mal, inplace = True)

# %%
df
# Out:
#                                           Name Ratings Positions    BIN  \
# 0                                       Player     OVR       POS    BIN
# 1           Karim Benzema\nReal Madrid | ESP 1      89        CF    19K
# 2        Thibaut Courtois\nReal Madrid | ESP 1      89        GK  28.8K
# 3                Casemiro\nReal Madrid | ESP 1      89       CDM   9.6K
# 4              Toni Kroos\nReal Madrid | ESP 1      88        CM    18K
# 5             Luka Modric\nReal Madrid | ESP 1      87        CM   9.4K
# 6                Carvajal\nReal Madrid | ESP 1      85        RB   4.6K
# 7             Eden Hazard\nReal Madrid | ESP 1      85        LW    15K
# 8             David Alaba\nReal Madrid | ESP 1      84        CB     6K
# 9         Antonio Rudiger\nReal Madrid | ESP 1      83        CB   3.5K
# 10      Federico Valverde\nReal Madrid | ESP 1      83        CM    12K
# 11          Ferland Mendy\nReal Madrid | ESP 1      83        LB   6.8K
# ...

# %%
nombre = []
for e in df['Name']:
    temp = e.split('\n')
    nombre.append(temp[0])
nombre
# Out:
# ['Player',
#  'Karim Benzema',
#  'Thibaut Courtois',
#  'Casemiro',
#  'Toni Kroos',
#  'Luka Modric',
#  'Carvajal',
#  'Eden Hazard',
#  'David Alaba',
#  'Antonio Rudiger',
#  'Federico Valverde',
#  'Ferland Mendy',
#  'Marco Asensio',
#  'Eder Militao',
#  'Gareth Bale',
#  'Isco',
#  'Nacho Fernandez',
#  'Lucas Vazquez',
#  'Vinicius Junior',
#  'Marcelo',
#  'Rodrygo',
#  'Luka Jovic',
#  'Aurelien Tchouameni',
#  'Odriozola',
#  'Eduardo Camavinga',
#  'Dani Ceballos']

# %%
df['Name'] = nombre

# %%
df
# Out:
#                      Name Ratings Positions    BIN      PAC      SHO      PAS  \
# 0                  Player     OVR       POS    BIN      PAC      SHO      PAS
# 1           Karim Benzema      89        CF    19K  PAC\n76  SHO\n86  PAS\n81
# 2        Thibaut Courtois      89        GK  28.8K  DIV\n84  HAN\n89  KIC\n74
# 3                Casemiro      89       CDM   9.6K  PAC\n65  SHO\n73  PAS\n76
# 4              Toni Kroos      88        CM    18K  PAC\n53  SHO\n81  PAS\n91
# 5             Luka Modric      87        CM   9.4K  PAC\n73  SHO\n76  PAS\n89
# 6                Carvajal      85        RB   4.6K  PAC\n80  SHO\n54  PAS\n78
# 7             Eden Hazard      85        LW    15K  PAC\n84  SHO\n80  PAS\n82
# 8             David Alaba      84        CB     6K  PAC\n77  SHO\n70  PAS\n81
# 9         Antonio Rudiger      83        CB   3.5K  PAC\n75  SHO\n43  PAS\n68
# 10      Federico Valverde      83        CM    12K  PAC\n86  SHO\n74  PAS\n78
# ...

# %%
new=[]
for e in df.PAC:
    bien= e.rstrip('\n')
    new.append(bien[4:])
    
new
# Out:
# ['',
#  '76',
#  '84',
#  '65',
#  '53',
#  '73',
#  '80',
#  '84',
#  '77',
#  '75',
#  '86',
#  '92',
#  '82',
#  '83',
#  '82',
#  '66',
#  '78',
#  '82',
#  '95',
#  '73',
#  '87',
#  '75',
#  '72',
#  '84',
#  '72',
#  '60']

# %%
df['PAC'] = new

# %%
new=[]
for e in df.SHO:
    bien= e.rstrip('\n')
    new.append(bien[4:])
    
new
# Out:
# ['',
#  '86',
#  '89',
#  '73',
#  '81',
#  '76',
#  '54',
#  '80',
#  '70',
#  '43',
#  '74',
#  '64',
#  '80',
#  '50',
#  '84',
#  '75',
#  '37',
#  '73',
#  '70',
#  '72',
#  '76',
#  '80',
#  '69',
#  '55',
#  '65',
#  '68']

# %%
df['SHO'] = new

# %%
new=[]
for e in df.PAS:
    bien= e.rstrip('\n')
    new.append(bien[4:])
    
new
# Out:
# ['',
#  '81',
#  '74',
#  '76',
#  '91',
#  '89',
#  '78',
#  '82',
#  '81',
#  '68',
#  '78',
#  '76',
#  '81',
#  '69',
#  '82',
#  '80',
#  '66',
#  '79',
#  '71',
#  '80',
#  '71',
#  '68',
#  '75',
#  '71',
#  '76',
#  '77']

# %%
df['PAS'] = new

# %%
new=[]
for e in df.DRI:
    bien= e.rstrip('\n')
    new.append(bien[4:])
    
new
# Out:
# ['',
#  '87',
#  '88',
#  '73',
#  '81',
#  '88',
#  '80',
#  '88',
#  '80',
#  '64',
#  '79',
#  '79',
#  '83',
#  '71',
#  '80',
#  '88',
#  '69',
#  '80',
#  '87',
#  '87',
#  '83',
#  '78',
#  '77',
#  '75',
#  '80',
#  '82']

# %%
df['DRI'] = new

# %%
new=[]
for e in df.DEF:
    bien= e.rstrip('\n')
    new.append(bien[4:])
    
new
# Out:
# ['',
#  '39',
#  '46',
#  '86',
#  '71',
#  '72',
#  '81',
#  '35',
#  '83',
#  '84',
#  '77',
#  '78',
#  '43',
#  '83',
#  '55',
#  '59',
#  '81',
#  '69',
#  '29',
#  '75',
#  '32',
#  '29',
#  '77',
#  '74',
#  '75',
#  '66']

# %%
df['DEF'] = new

# %%
new=[]
for e in df.PHY:
    bien= e.rstrip('\n')
    new.append(bien[4:])
    
new
# Out:
# ['',
#  '77',
#  '86',
#  '90',
#  '68',
#  '66',
#  '80',
#  '63',
#  '76',
#  '84',
#  '80',
#  '84',
#  '62',
#  '82',
#  '70',
#  '59',
#  '80',
#  '69',
#  '66',
#  '71',
#  '56',
#  '74',
#  '82',
#  '65',
#  '77',
#  '67']

# %%
df['PHY'] = new

# %%
df['Club'] = 'Madrid'

# %%
df['Temporada'] = '2021/2022'

# %%
df.drop(columns = 'BIN')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [159], in <cell line: 1>()
# ----> 1 df.drop(columns = 'BIN')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
df.drop(df.index[0], inplace = True)

# %%
url_barca = 'https://www.futwiz.com/en/fifa22/players?page=0&leagues[]=53&teams[]=241&release=nifgold'

# %%
driver.get(url_barca)

# %%
filas = driver.find_element(By.TAG_NAME, 'tbody')

data_barca = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in filas.find_elements(By.TAG_NAME, 'tr')]

# %%
data_barca
# Out:
# [['',
#   'Player',
#   'OVR',
#   'POS',
#   'BIN',
#   'PAC',
#   'SHO',
#   'PAS',
#   'DRI',
#   'DEF',
#   'PHY',
#   'S/M',
#   'W/F',
#   'W/Rs',
#   'Foot',
#   'Stats'],
#  ['',
#   'Marc-Andre ter Stegen\nFC Barcelona | ESP 1',
#   '90',
#   'GK',
#   '11.5K',
#   'DIV\n88',
#   'HAN\n85',
#   'KIC\n88',
#   'REF\n90',
#   'SPD\n43',
#   'POS\n88',
#   '1',
#   '4',
#   'M/M',
#   'Right',
#   '1,005'],
#  ['',
#   'Frenkie de Jong\nFC Barcelona | ESP 1',
#   '87',
#   'CM',
#   '7.9K',
#   'PAC\n81',
#   'SHO\n69',
#   'PAS\n85',
#   'DRI\n88',
#   'DEF\n77',
#   'PHY\n78',
#   '4',
#   '3',
#   'H/M',
#   'Right',
#   '2,180'],
#  ['',
#   'Sergio Aguero\nFC Barcelona | ESP 1',
#   '87',
#   'ST',
#   '43K',
#   'PAC\n71',
#   'SHO\n89',
#   'PAS\n75',
#   'DRI\n87',
#   'DEF\n33',
#   'PHY\n69',
#   '4',
#   '4',
#   'H/M',
#   'Right',
#   '2,009'],
#  ['',
#   'Jordi Alba\nFC Barcelona | ESP 1',
#   '86',
#   'LB',
#   '7K',
#   'PAC\n86',
#   'SHO\n69',
# ...

# %%
cols_barca = ['','Name','Ratings','Positions','BIN','PAC','SHO','PAS','DRI','DEF','PHY','S/M','W/F','W/Rs','Foot','Stats']

# %%
df_barca = pd.DataFrame(data_barca, columns = cols_barca)

# %%
df_barca
# Out:
#                                                  Name Ratings Positions  \
# 0                                              Player     OVR       POS
# 1         Marc-Andre ter Stegen\nFC Barcelona | ESP 1      90        GK
# 2               Frenkie de Jong\nFC Barcelona | ESP 1      87        CM
# 3                 Sergio Aguero\nFC Barcelona | ESP 1      87        ST
# 4                    Jordi Alba\nFC Barcelona | ESP 1      86        LB
# 5               Sergio Busquets\nFC Barcelona | ESP 1      86       CDM
# 6                 Memphis Depay\nFC Barcelona | ESP 1      85        CF
# 7     Pierre-Emerick Aubameyang\nFC Barcelona | ESP 1      85        ST
# 8         Franck Yannick Kessie\nFC Barcelona | ESP 1      84       CDM
# 9                         Pique\nFC Barcelona | ESP 1      84        CB
# 10              Ousmane Dembele\nFC Barcelona | ESP 1      83        RW
# 11              Clement Lenglet\nFC Barcelona | ESP 1      82        CB
# ...

# %%
cols_barca_mal = ['S/M','W/F','W/Rs','Foot','Stats','BIN']
df_barca.drop(columns = cols_barca_mal)
# Out:
#                                                  Name Ratings Positions  \
# 0                                              Player     OVR       POS
# 1         Marc-Andre ter Stegen\nFC Barcelona | ESP 1      90        GK
# 2               Frenkie de Jong\nFC Barcelona | ESP 1      87        CM
# 3                 Sergio Aguero\nFC Barcelona | ESP 1      87        ST
# 4                    Jordi Alba\nFC Barcelona | ESP 1      86        LB
# 5               Sergio Busquets\nFC Barcelona | ESP 1      86       CDM
# 6                 Memphis Depay\nFC Barcelona | ESP 1      85        CF
# 7     Pierre-Emerick Aubameyang\nFC Barcelona | ESP 1      85        ST
# 8         Franck Yannick Kessie\nFC Barcelona | ESP 1      84       CDM
# 9                         Pique\nFC Barcelona | ESP 1      84        CB
# 10              Ousmane Dembele\nFC Barcelona | ESP 1      83        RW
# 11              Clement Lenglet\nFC Barcelona | ESP 1      82        CB
# ...

# %%
nom = []
for e in df_barca['Name']:
    temp = e.split('\n')
    nom.append(temp[0])
nom
# Out:
# ['Player',
#  'Marc-Andre ter Stegen',
#  'Frenkie de Jong',
#  'Sergio Aguero',
#  'Jordi Alba',
#  'Sergio Busquets',
#  'Memphis Depay',
#  'Pierre-Emerick Aubameyang',
#  'Franck Yannick Kessie',
#  'Pique',
#  'Ousmane Dembele',
#  'Clement Lenglet',
#  'Neto',
#  'Coutinho',
#  'Ferran Torres',
#  'Miralem Pjanic',
#  'Pedri',
#  'Sergi Roberto',
#  'Andreas Christensen',
#  'Samuel Umtiti',
#  'Luuk de Jong',
#  'Dani Alves',
#  'Adama Traore',
#  'Ronald Araujo',
#  'Martin Braithwaite',
#  'Eric Garcia']

# %%
df_barca['Name'] = nom

# %%
new=[]
for e in df_barca.PHY:
    bien= e.rstrip('\n')
    new.append(bien[4:])
    
new
# Out:
# ['',
#  '88',
#  '78',
#  '69',
#  '71',
#  '75',
#  '79',
#  '69',
#  '87',
#  '78',
#  '56',
#  '79',
#  '79',
#  '59',
#  '66',
#  '67',
#  '63',
#  '73',
#  '72',
#  '78',
#  '75',
#  '63',
#  '81',
#  '76',
#  '74',
#  '72']

# %%
df_barca['PHY'] = new

# %%
new=[]
for e in df_barca.DEF:
    bien= e.rstrip('\n')
    new.append(bien[4:])
    
new
# Out:
# ['',
#  '43',
#  '77',
#  '33',
#  '77',
#  '82',
#  '30',
#  '35',
#  '82',
#  '85',
#  '36',
#  '83',
#  '54',
#  '52',
#  '35',
#  '75',
#  '66',
#  '76',
#  '83',
#  '80',
#  '46',
#  '72',
#  '38',
#  '79',
#  '35',
#  '79']

# %%
df_barca['DEF'] = new

# %%
new=[]
for e in df_barca.DRI:
    bien= e.rstrip('\n')
    new.append(bien[4:])
    
new
# Out:
# ['',
#  '90',
#  '88',
#  '87',
#  '83',
#  '80',
#  '84',
#  '80',
#  '80',
#  '68',
#  '86',
#  '66',
#  '81',
#  '88',
#  '82',
#  '81',
#  '84',
#  '77',
#  '68',
#  '67',
#  '70',
#  '78',
#  '86',
#  '52',
#  '79',
#  '66']

# %%
df_barca['DRI'] = new

# %%
new=[]
for e in df_barca.PAS:
    bien= e.rstrip('\n')
    new.append(bien[4:])
    
new
# Out:
# ['',
#  '88',
#  '85',
#  '75',
#  '81',
#  '79',
#  '82',
#  '75',
#  '74',
#  '71',
#  '77',
#  '67',
#  '78',
#  '80',
#  '78',
#  '83',
#  '79',
#  '80',
#  '65',
#  '68',
#  '71',
#  '78',
#  '67',
#  '53',
#  '72',
#  '65']

# %%
df_barca['PAS'] = new

# %%
new=[]
for e in df_barca.SHO:
    bien= e.rstrip('\n')
    new.append(bien[4:])
    
new
# Out:
# ['',
#  '85',
#  '69',
#  '89',
#  '69',
#  '62',
#  '83',
#  '85',
#  '74',
#  '61',
#  '77',
#  '45',
#  '79',
#  '79',
#  '79',
#  '68',
#  '65',
#  '63',
#  '31',
#  '62',
#  '78',
#  '71',
#  '66',
#  '36',
#  '76',
#  '44']

# %%
df_barca['SHO'] = new

# %%
new=[]
for e in df_barca.PAC:
    bien= e.rstrip('\n')
    new.append(bien[4:])
    
new
# Out:
# ['',
#  '88',
#  '81',
#  '71',
#  '86',
#  '42',
#  '82',
#  '89',
#  '78',
#  '58',
#  '93',
#  '72',
#  '83',
#  '69',
#  '82',
#  '65',
#  '78',
#  '76',
#  '65',
#  '65',
#  '50',
#  '71',
#  '96',
#  '77',
#  '80',
#  '65']

# %%
df_barca['PAC'] = new

# %%
columnas_malas_barca = ['S/M','W/F','W/Rs','Foot','Stats','BIN']
df_barca.drop(columns = columnas_malas_barca, inplace = True)

# %%
df_barca
# Out:
#                            Name Ratings Positions PAC SHO PAS DRI DEF PHY
# 0                        Player     OVR       POS
# 1         Marc-Andre ter Stegen      90        GK  88  85  88  90  43  88
# 2               Frenkie de Jong      87        CM  81  69  85  88  77  78
# 3                 Sergio Aguero      87        ST  71  89  75  87  33  69
# 4                    Jordi Alba      86        LB  86  69  81  83  77  71
# 5               Sergio Busquets      86       CDM  42  62  79  80  82  75
# 6                 Memphis Depay      85        CF  82  83  82  84  30  79
# 7     Pierre-Emerick Aubameyang      85        ST  89  85  75  80  35  69
# 8         Franck Yannick Kessie      84       CDM  78  74  74  80  82  87
# 9                         Pique      84        CB  58  61  71  68  85  78
# 10              Ousmane Dembele      83        RW  93  77  77  86  36  56
# 11              Clement Lenglet      82        CB  72  45  67  66  83  79
# ...

# %%
df_barca['Club'] = 'Fc Barcelona'

# %%
df_barca['League'] = 'LaLiga Santander'

# %%
df_barca.drop(df_barca.index[0], inplace = True)

# %%
df_barca['Temporada'] = '2021/2022'
df_barca
# Out:
#                          Name Ratings Positions PAC SHO PAS DRI DEF PHY  \
# 1       Marc-Andre ter Stegen      90        GK  88  85  88  90  43  88
# 2             Frenkie de Jong      87        CM  81  69  85  88  77  78
# 3               Sergio Aguero      87        ST  71  89  75  87  33  69
# 4                  Jordi Alba      86        LB  86  69  81  83  77  71
# 5             Sergio Busquets      86       CDM  42  62  79  80  82  75
# 6               Memphis Depay      85        CF  82  83  82  84  30  79
# 7   Pierre-Emerick Aubameyang      85        ST  89  85  75  80  35  69
# 8       Franck Yannick Kessie      84       CDM  78  74  74  80  82  87
# 9                       Pique      84        CB  58  61  71  68  85  78
# 10            Ousmane Dembele      83        RW  93  77  77  86  36  56
# 11            Clement Lenglet      82        CB  72  45  67  66  83  79
# 12                       Neto      82        GK  83  79  78  81  54  79
# ...

# %%
df.drop(columns = 'BIN', inplace = True)

# %%
df
# Out:
#                    Name Ratings Positions PAC SHO PAS DRI DEF PHY    Club  \
# 1         Karim Benzema      89        CF  76  86  81  87  39  77  Madrid
# 2      Thibaut Courtois      89        GK  84  89  74  88  46  86  Madrid
# 3              Casemiro      89       CDM  65  73  76  73  86  90  Madrid
# 4            Toni Kroos      88        CM  53  81  91  81  71  68  Madrid
# 5           Luka Modric      87        CM  73  76  89  88  72  66  Madrid
# 6              Carvajal      85        RB  80  54  78  80  81  80  Madrid
# 7           Eden Hazard      85        LW  84  80  82  88  35  63  Madrid
# 8           David Alaba      84        CB  77  70  81  80  83  76  Madrid
# 9       Antonio Rudiger      83        CB  75  43  68  64  84  84  Madrid
# 10    Federico Valverde      83        CM  86  74  78  79  77  80  Madrid
# 11        Ferland Mendy      83        LB  92  64  76  79  78  84  Madrid
# 12        Marco Asensio      83        RW  82  80  81  83  43  62  Madrid
# ...

# %%
df_real_madrid['Temporada'] = '2022/2023'
df_real_madrid
# Out:
#                             Name  Ratings      Position  PAC  SHO  PAS  DRI  \
# 0                  Karim Benzema       91        CF  ST   80   88   83   87
# 1               Thibaut Courtois       90            GK   84   89   75   90
# 2                    Luka Modric       89            CM   75   78   90   89
# 3                     Toni Kroos       89            CM   55   82   91   82
# 4                    David Alaba       88            CB   81   66   85   83
# 5                Antonio Rüdiger       87            CB   82   53   71   67
# 6              Federico Valverde       87            CM   90   78   84   82
# 7                Vinícius Júnior       86        LW  LM   95   79   74   90
# 8                   Éder Militão       84            CB   86   50   70   72
# 9                       Carvajal       84       RB  RWB   82   54   77   80
# 10                   Eden Hazard       84        LW  LM   83   80   82   87
# ...

# %%
df_real_madrid['Name'].replace(['Karim Benzema','Thibaut Courtois','Luka Modric','Toni Kroos','David Alaba','Antonio Rüdiger','Federico Valverde','Vinícius Júnior','Éder Militão','Carvajal','Eden Hazard','Ferland Mendy','Marco Asensio','Aurélien Tchouaméni','Nacho Fernández','Rodrygo','Lucas Vázquez','Camavinga','Odriozola','Dani Ceballos','Vallejo','Andriy Lunin','Mariano','Peter González Carmona','Rafael Obrador Burguera','Iker Bravo Solanilla','Sergio Arribas Calvo','Luis López','Noel López de la Fuente','Lucas Cañizares Conchello','Takuhiro Nakai','Julen Jon Guerrero Landabaso'],['Karim Benzema','Thibaut Courtois','Luka Modric','Toni Kroos','David Alaba','Antonio Rudiger','Federico Valverde','Vinicius Junior','Eder Militao','Carvajal','Eden Hazard','Ferland Mendy','Marco Asensio','Aurelien Tchouameni','Nacho Fernandez','Rodrygo','Lucas Vazquez','Eduardo Camavinga','Odriozola','Dani Ceballos','Vallejo','Andriy Lunin','Mariano','Peter González Carmona','Rafael Obrador Burguera','Iker Bravo Solanilla','Sergio Arribas Calvo','Luis López','Noel López de la Fuente','Lucas Cañizares Conchello','Takuhiro Nakai','Julen Jon Guerrero Landabaso'], inplace = True)

# %%
df_real_madrid
# Out:
#                             Name  Ratings      Position  PAC  SHO  PAS  DRI  \
# 0                  Karim Benzema       91        CF  ST   80   88   83   87
# 1               Thibaut Courtois       90            GK   84   89   75   90
# 2                    Luka Modric       89            CM   75   78   90   89
# 3                     Toni Kroos       89            CM   55   82   91   82
# 4                    David Alaba       88            CB   81   66   85   83
# 5                Antonio Rudiger       87            CB   82   53   71   67
# 6              Federico Valverde       87            CM   90   78   84   82
# 7                Vinicius Junior       86        LW  LM   95   79   74   90
# 8                   Eder Militao       84            CB   86   50   70   72
# 9                       Carvajal       84       RB  RWB   82   54   77   80
# 10                   Eden Hazard       84        LW  LM   83   80   82   87
# ...

# %%
df_fc_barcelona['Temporada'] = '2022/2023'
df_fc_barcelona
# Out:
#                        Name  Ratings    Position  PAC  SHO  PAS  DRI  DEF  \
# 0        Robert Lewandowski       91      ST  CF   75   91   79   86   44
# 1              Gerard Piqué       89          CB   83   58   77   74   88
# 2                ter Stegen       88          GK   86   85   87   90   47
# 3           Frenkie de Jong       87          CM   82   69   86   87   77
# 4                  Raphinha       86      RW  RM   94   82   81   88   53
# 5                     Pedri       86          CM   80   69   83   88   69
# 6           Sergio Busquets       85         CDM   42   62   79   79   82
# 7             Memphis Depay       85   CF  ST,LW   83   84   82   86   30
# 8          Jordi Alba Ramos       85     LB  LWB   84   70   82   82   77
# 9              Jules Koundé       84          CB   84   45   64   74   85
# 10                   Kessié       84     CDM  CM   78   76   74   79   82
# 11          Ousmane Dembélé       83      RW  RM   93   77   79   87   36
# ...

# %%
df_fc_barcelona['Name'].replace(['Robert Lewandowski','Gerard Piqué','ter Stegen','Frenkie de Jong','Raphinha','Pedri','Sergio Busquets','Memphis Depay','Jordi Alba Ramos','Jules Koundé','Kessié','Ousmane Dembélé','Ronald Araujo','Ferrán Torres','Andreas Christensen','Sergi Roberto','Anssumane Fati','Páez Gavira','Héctor Bellerín','Marcos Alonso Mendoza','Eric García Martret','Ignacio Peña Sotorres','Álex Balde','Pablo Torre Carral','Arnau Tenas Ureña','Ilias Akhomach Chakkour','Roberto Fernández Jaén','Emre Demir','Álvaro Sanz Catalán','Hiroki Abe'],['Robert Lewandowski','Gerard Piqué','Marc-Andre ter Stegen','Frenkie de Jong','Raphinha','Pedri','Sergio Busquets','Memphis Depay','Jordi Alba','Jules Koundé','Franck Yannick Kessie','Ousmane Dembélé','Ronald Araujo','Ferrán Torres','Andreas Christensen','Sergi Roberto','Anssumane Fati','Páez Gavira','Héctor Bellerín','Marcos Alonso Mendoza','Eric Garcia','Ignacio Peña Sotorres','Álex Balde','Pablo Torre Carral','Arnau Tenas Ureña','Ilias Akhomach Chakkour','Roberto Fernández Jaén','Emre Demir','Álvaro Sanz Catalán','Hiroki Abe'], inplace = True)

# %%
df_fc_barcelona['Name'].replace(['Gerard Piqué','Ousmane Dembélé','Ferrán Torres'],['Pique','Ousmane Dembele','Ferran Torres'], inplace = True)

# %%
df_fc_barcelona
# Out:
#                        Name  Ratings    Position  PAC  SHO  PAS  DRI  DEF  \
# 0        Robert Lewandowski       91      ST  CF   75   91   79   86   44
# 1                     Pique       89          CB   83   58   77   74   88
# 2     Marc-Andre ter Stegen       88          GK   86   85   87   90   47
# 3           Frenkie de Jong       87          CM   82   69   86   87   77
# 4                  Raphinha       86      RW  RM   94   82   81   88   53
# 5                     Pedri       86          CM   80   69   83   88   69
# 6           Sergio Busquets       85         CDM   42   62   79   79   82
# 7             Memphis Depay       85   CF  ST,LW   83   84   82   86   30
# 8                Jordi Alba       85     LB  LWB   84   70   82   82   77
# 9              Jules Koundé       84          CB   84   45   64   74   85
# 10    Franck Yannick Kessie       84     CDM  CM   78   76   74   79   82
# 11          Ousmane Dembele       83      RW  RM   93   77   79   87   36
# ...

# %%
len(df_fc_barcelona.Name.unique())
# Out:
# 30

# %%
matches = pd.read_clipboard()
matches
# Out:
#     2022/2023  Madrid   Barça  3-1
# 0   2021/2022  Madrid   Barça  0-4
# 1   2021/2022   Barça  Madrid  1-2
# 2   2020/2021  Madrid   Barça  2-1
# 3   2020/2021   Barça  Madrid  1-3
# 4   2019/2020  Madrid   Barça  2-0
# 5   2019/2020   Barça  Madrid  0-0
# 6   2018/2019  Madrid   Barça  0-1
# 7   2018/2019   Barça  Madrid  5-1
# 8   2017/2018   Barça  Madrid  2-2
# 9   2017/2018  Madrid   Barça  0-3
# 10  2016/2017  Madrid   Barça  2-3
# 11  2016/2017   Barça  Madrid  1-1
# 12  2015/2016   Barça  Madrid  1-2
# 13  2015/2016  Madrid   Barça  0-4
# 14  2014/2015   Barça  Madrid  2-1
# 15  2014/2015  Madrid   Barça  3-1
# 16  2013/2014  Madrid   Barça  3-4
# 17  2013/2014   Barça  Madrid  2-1
# 18  2012/2013  Madrid   Barça  2-1
# 19  2012/2013   Barça  Madrid  2-2
# 20  2011/2012   Barça  Madrid  1-2
# 21  2011/2012  Madrid   Barça  1-3
# 22  2010/2011  Madrid   Barça  1-1
# 23  2010/2011   Barça  Madrid  5-0
# 24  2009/2010  Madrid   Barça  0-2
# 25  2009/2010   Barça  Madrid  1-0
# ...

# %%
matches.columns
# Out:
# Index(['2022/2023', 'Madrid', 'Barça', '3-1'], dtype='object')

# %%
headers = ['Temporada', 'Club Local', 'Club Visitante', 'Resultado']
matches.columns = headers

# %%
matches['Club Local'].replace(['Madrid', 'Barça'],['Real Madrid','FC Barcelona'], inplace = True)

# %%
matches['Club Visitante'].replace(['Madrid', 'Barça'],['Real Madrid','FC Barcelona'], inplace = True)

# %%
df.drop(columns = '', inplace = True)

# %%
df_barca.drop(columns = '', inplace = True)

# %%
matches
# Out:
#     Temporada    Club Local Club Visitante Resultado
# 0   2021/2022   Real Madrid   FC Barcelona       0-4
# 1   2021/2022  FC Barcelona    Real Madrid       1-2
# 2   2020/2021   Real Madrid   FC Barcelona       2-1
# 3   2020/2021  FC Barcelona    Real Madrid       1-3
# 4   2019/2020   Real Madrid   FC Barcelona       2-0
# 5   2019/2020  FC Barcelona    Real Madrid       0-0
# 6   2018/2019   Real Madrid   FC Barcelona       0-1
# 7   2018/2019  FC Barcelona    Real Madrid       5-1
# 8   2017/2018  FC Barcelona    Real Madrid       2-2
# 9   2017/2018   Real Madrid   FC Barcelona       0-3
# 10  2016/2017   Real Madrid   FC Barcelona       2-3
# 11  2016/2017  FC Barcelona    Real Madrid       1-1
# 12  2015/2016  FC Barcelona    Real Madrid       1-2
# 13  2015/2016   Real Madrid   FC Barcelona       0-4
# 14  2014/2015  FC Barcelona    Real Madrid       2-1
# 15  2014/2015   Real Madrid   FC Barcelona       3-1
# 16  2013/2014   Real Madrid   FC Barcelona       3-4
# ...

# %%
matches.drop_duplicates(subset = ['Temporada'], inplace = True)

# %%
matches.reset_index(drop = True, inplace = True)

# %%
matches
# Out:
#     Temporada    Club Local Club Visitante Resultado
# 0   2021/2022   Real Madrid   FC Barcelona       0-4
# 1   2020/2021   Real Madrid   FC Barcelona       2-1
# 2   2019/2020   Real Madrid   FC Barcelona       2-0
# 3   2018/2019   Real Madrid   FC Barcelona       0-1
# 4   2017/2018  FC Barcelona    Real Madrid       2-2
# 5   2016/2017   Real Madrid   FC Barcelona       2-3
# 6   2015/2016  FC Barcelona    Real Madrid       1-2
# 7   2014/2015  FC Barcelona    Real Madrid       2-1
# 8   2013/2014   Real Madrid   FC Barcelona       3-4
# 9   2012/2013   Real Madrid   FC Barcelona       2-1
# 10  2011/2012  FC Barcelona    Real Madrid       1-2
# 11  2010/2011   Real Madrid   FC Barcelona       1-1
# 12  2009/2010   Real Madrid   FC Barcelona       0-2
# 13  2008/2009   Real Madrid   FC Barcelona       2-6
# 14  2007/2008   Real Madrid   FC Barcelona       4-1
# 15  2006/2007  FC Barcelona    Real Madrid       3-3
# 16  2005/2006  FC Barcelona    Real Madrid       1-1
# ...

# %% [markdown]
# ### Base de datos con las tablas de arriba

# %%
from sqlalchemy import create_engine

# %%
str_conn = 'mysql+pymysql://root:password@localhost:3306'

cursor = create_engine(str_conn)


cursor.execute('drop database if exists futbol;')

cursor.execute('create database futbol;')

# %%
str_conn = 'mysql+pymysql://root:password@localhost:3306/futbol'

cursor = create_engine(str_conn)

# %%
matches.to_sql(name = 'matches', con = cursor, if_exists = 'replace', index = False)
# Out:
# 22

# %%
df.to_sql(name = 'madrid_2022', con = cursor, if_exists = 'replace', index = False)
# Out:
# 25

# %%
df_barca.to_sql(name = 'barca_2022', con = cursor, if_exists = 'replace', index = False)
# Out:
# 25

# %%
df_fc_barcelona.to_sql(name = 'barca_2023', con = cursor, if_exists = 'replace', index = False)
# Out:
# 30

# %%
df_real_madrid.to_sql(name = 'madrid_2023', con = cursor, if_exists = 'replace', index = False)
# Out:
# 32
